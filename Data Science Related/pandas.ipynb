# %%
import pandas as p

# %% [markdown]
# - DataFrame: 2D Array
# - DataSeries: Column

# %%
p.DataFrame({'name': ['a', 'b', 'c'], 'point': [1, 2, 3]})
# Out:
#   name  point
# 0    a      1
# 1    b      2
# 2    c      3

# %%
df = p.DataFrame([['a', 1],
                  ['b', 2],
                  ['c', 3]
                 ])
df
# Out:
#    0  1
# 0  a  1
# 1  b  2
# 2  c  3

# %%
df = p.read_csv("Advertising.csv", usecols=['TV', 'Radio', 'Newspaper', 'Sales'])
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df = p.read_csv("Advertising.csv").drop('Unnamed: 0', axis=1)
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df = p.read_csv("Advertising.csv")
df.drop('Unnamed: 0', axis=1)       # makes copy
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df = p.read_csv("Advertising.csv")
df.drop('Unnamed: 0', axis=1, inplace=True)        #edits inplace
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df = p.read_csv("housing.csv")
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
df = p.read_csv("iris.csv", index_col='Id')
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df['SepalLengthCm']  #dataserie
# Out:
# Id
# 1      5.1
# 2      4.9
# 3      4.7
# 4      4.6
# 5      5.0
#       ...
# 146    6.7
# 147    6.3
# 148    6.5
# 149    6.2
# 150    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df['SepalLengthCm'][2]      #incorrect
# Out:
# np.float64(4.9)

# %%
df.loc[2, ['SepalLengthCm']]        #correct
# Out:
# SepalLengthCm    4.9
# Name: 2, dtype: object

# %%
df.loc[2:5, ['Species', 'SepalLengthCm']]
# Out:
#         Species  SepalLengthCm
# Id
# 2   Iris-setosa            4.9
# 3   Iris-setosa            4.7
# 4   Iris-setosa            4.6
# 5   Iris-setosa            5.0

# %%
df.iloc[1:5, [2,3,4]]      # just works with indides
# Out:
#     PetalLengthCm  PetalWidthCm      Species
# Id
# 2             1.4           0.2  Iris-setosa
# 3             1.3           0.2  Iris-setosa
# 4             1.5           0.2  Iris-setosa
# 5             1.4           0.2  Iris-setosa

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df = df.drop(2)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# 6              5.4           3.9            1.7           0.4     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.reset_index(inplace=True)
df
# Out:
#      level_0  index   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# 0          0      0    1            5.1           3.5            1.4
# 1          1      1    3            4.7           3.2            1.3
# 2          2      2    4            4.6           3.1            1.5
# 3          3      3    5            5.0           3.6            1.4
# 4          4      4    6            5.4           3.9            1.7
# ..       ...    ...  ...            ...           ...            ...
# 144      144    144  146            6.7           3.0            5.2
# 145      145    145  147            6.3           2.5            5.0
# 146      146    146  148            6.5           3.0            5.2
# 147      147    147  149            6.2           3.4            5.4
# 148      148    148  150            5.9           3.0            5.1
#
#      PetalWidthCm         Species
# 0             0.2     Iris-setosa
# 1             0.2     Iris-setosa
# ...

# %%
df2 = df.iloc[: , 4]
df2
# Out:
# 0      3.5
# 1      3.2
# 2      3.1
# 3      3.6
# 4      3.9
#       ...
# 144    3.0
# 145    2.5
# 146    3.0
# 147    3.4
# 148    3.0
# Name: SepalWidthCm, Length: 149, dtype: float64

# %%
f = df2 > 3.5
f
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 144    False
# 145    False
# 146    False
# 147    False
# 148    False
# Name: SepalWidthCm, Length: 149, dtype: bool

# %%
df.loc[f, :]         #filtering
# Out:
#      level_0  index   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# 3          3      3    5            5.0           3.6            1.4
# 4          4      4    6            5.4           3.9            1.7
# 9          9      9   11            5.4           3.7            1.5
# 13        13     13   15            5.8           4.0            1.2
# 14        14     14   16            5.7           4.4            1.5
# 15        15     15   17            5.4           3.9            1.3
# 17        17     17   19            5.7           3.8            1.7
# 18        18     18   20            5.1           3.8            1.5
# 20        20     20   22            5.1           3.7            1.5
# 21        21     21   23            4.6           3.6            1.0
# 31        31     31   33            5.2           4.1            1.5
# 32        32     32   34            5.5           4.2            1.4
# 43        43     43   45            5.1           3.8            1.9
# ...

# %%
df.describe()      # describes numeric columns
# Out:
#           level_0       index          Id  SepalLengthCm  SepalWidthCm  \
# count  149.000000  149.000000  149.000000     149.000000    149.000000
# mean    74.000000   74.000000   75.993289       5.849664      3.054362
# std     43.156691   43.156691   43.168353       0.827208      0.435034
# min      0.000000    0.000000    1.000000       4.300000      2.000000
# 25%     37.000000   37.000000   39.000000       5.100000      2.800000
# 50%     74.000000   74.000000   76.000000       5.800000      3.000000
# 75%    111.000000  111.000000  113.000000       6.400000      3.300000
# max    148.000000  148.000000  150.000000       7.900000      4.400000
#
#        PetalLengthCm  PetalWidthCm
# count     149.000000    149.000000
# mean        3.774497      1.205369
# std         1.759651      0.761292
# min         1.000000      0.100000
# 25%         1.600000      0.300000
# 50%         4.400000      1.300000
# 75%         5.100000      1.800000
# max         6.900000      2.500000

# %%
df['Species'].describe()      #describe non-numeric column
# Out:
# count                 149
# unique                  3
# top       Iris-versicolor
# freq                   50
# Name: Species, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   level_0        149 non-null    int64
#  1   index          149 non-null    int64
#  2   Id             149 non-null    int64
#  3   SepalLengthCm  149 non-null    float64
#  4   SepalWidthCm   149 non-null    float64
#  5   PetalLengthCm  149 non-null    float64
#  6   PetalWidthCm   149 non-null    float64
#  7   Species        149 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 9.4+ KB
