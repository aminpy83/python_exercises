# %% [markdown]
# # abs()

# %%
abs(-2.43)
# Out:
# 2.43

# %%
abs(1-2j)
# Out:
# 2.23606797749979

# %% [markdown]
# # iter() & aiter() & anext() & next()

# %%
l = [1, 2, 3]

# %%
i = iter(l)
print(next(i))
print(next(i))
print(next(i))
print(next(i, 0))
# Out:
# 1
# 2
# 3
# 0

# %%
async def agen():
    for i in range(2):
        yield i

async def main():
    it = aiter(agen())

    print(await anext(it))  # 0
    print(await anext(it))  # 1


await main()
# Out:
# 0
# 1

# %% [markdown]
# # all()
# - Return True if all elements of the iterable are true (or if the iterable is empty)
# # any()
# - Return True if any element of the iterable is true. If the iterable is empty, return False.

# %%
print(all(l))
print(any(l))
# Out:
# True
# True

# %%
x = []
b = [True, False]

# %%
print(all(x))
print(any(x))
# Out:
# True
# False

# %%
print(all(b))
print(any(b))
# Out:
# False
# True

# %% [markdown]
# # ascii()
# - As repr(), return a string containing a printable representation of an object, but escape the non-ASCII characters in the string returned by repr() using \x, \u, or \U escapes

# %%
ascii("abc سلام")
# Out:
# "'abc \\u0633\\u0644\\u0627\\u0645'"

# %% [markdown]
# # bin() & format() & bool()
# - Convert an integer number to a binary string prefixed with “0b”. The result is a valid Python expression. If integer is not a Python int object, it has to define an __index__() method that returns an integer

# %%
print(bin(2))
print(format(16, '#0o'))
print(format(16, '0o'))
# Out:
# 0b10
# 0o20
# 20

# %%
bool(1)
# Out:
# True

# %% [markdown]
# # bytearray() & bytes()
# - Return a new array of bytes. The bytearray class is a mutable sequence of integers in the range 0 <= x < 256
# - Return a new “bytes” object which is an immutable sequence of integers in the range 0 <= x < 256

# %%
a = bytearray('zvdc', 'utf-8')
print(a)
a[0] = 97
print(a)
# Out:
# bytearray(b'zvdc')
# bytearray(b'avdc')

# %%
a = bytes('zvdc', 'utf-8')
a
# Out:
# b'zvdc'

# %% [markdown]
# # callable()
# - Return True if the object argument appears callable, False if not. If this returns True, it is still possible that a call fails, but if it is False, calling object will never succeed. Note that classes are callable (calling a class returns a new instance); instances are callable if their class has a __call__() method.

# %%
print(callable(1))
print(callable(sum))
# Out:
# False
# True

# %% [markdown]
# # chr()
# - Return the string representing a character with the specified Unicode code point.
# - The valid range for the argument is from 0 through 1,114,111 (0x10FFFF in base 16). ValueError will be raised if it is outside that range.

# %%
print(chr(0))
print(chr(97))
print(chr(61))
# Out:
# a
# =

# %% [markdown]
# # compile()
# - Compile the source into a code or AST object. Code objects can be executed by exec() or eval(). source can either be a normal string, a byte string, or an AST object.
# - compile(source, filename, mode)

# %%
code = "for i in range(3): print(i)"
obj = compile(code, "<string>", "exec")
exec(obj)
# Out:
# 0
# 1
# 2

# %% [markdown]
# # complex()
# - Convert a single string or number to a complex number, or create a complex number from real and imaginary parts.

# %%
complex(-1)
# Out:
# (-1+0j)

# %% [markdown]
# # delattr() & dict()
# -  The function deletes the named attribute, provided the object allows it.

# %%
class A:
    x = 10

obj = A()
print(obj.x)   # 10

delattr(A, "x")

print(obj.x)
# Out:
# 10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 9
#       5 print(obj.x)   # 10
#       7 delattr(A, "x")
# ----> 9 print(obj.x)
#
# AttributeError: 'A' object has no attribute 'x'

# %%
v = {'a' : 1}
dict(v)
# Out:
# {'a': 1}

# %% [markdown]
# # dir()
# - Without arguments, return the list of names in the current local scope.
# - With an argument, attempt to return a list of valid attributes for that object.

# %%
dir(v)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %% [markdown]
# # divmod()
# - Take two (non-complex) numbers as arguments and return a pair of numbers consisting of their quotient and remainder when using integer division.

# %%
divmod(15,4)
# Out:
# (3, 3)

# %% [markdown]
# # enumerate()
# - Return an enumerate object. iterable must be a sequence, an iterator, or some other object which supports iteration.
# - The __next__() method of the iterator returned by enumerate() returns a tuple containing a count (from start which defaults to 0) and the values obtained from iterating over iterable.

# %%
a = [1, 2, 3, 4]
for i in enumerate(a):
    print(i)
# Out:
# (0, 1)
# (1, 2)
# (2, 3)
# (3, 4)

# %%
list(enumerate(a, 10))
# Out:
# [(10, 1), (11, 2), (12, 3), (13, 4)]

# %% [markdown]
# # eval()
#  - __Warning This function executes arbitrary code. Calling it with user-supplied input may lead to security vulnerabilities.__
#  - eval(expression, globals=None, locals=None)
#  -   safe_globals = {"__builtins__": {}}
#  -   eval("2 + 2", safe_globals)

# %%
formula = "a + b * 10"
print(eval(formula, {"a": 2, "b": 5}))
# Out:
# 52

# %%
s = "{'x': 1, 'y': 2}"
d = eval(s)
print(d["x"])
# Out:
# 1

# %% [markdown]
# # exec()
# - This function supports dynamic execution of Python code.
# -  __Warning This function executes arbitrary code. Calling it with user-supplied input may lead to security vulnerabilities.__

# %%
code = """
def hello(name):
    return "Hello " + name
"""

namespace = {}
exec(code, namespace)

print(namespace["hello"]("Amin"))
# Out:
# Hello Amin

# %% [markdown]
# # filter() & map()

# %%
nums = [1, 2, 3, 4]
result = map(lambda x: x * 2, nums)
print(list(result))
# Out:
# [2, 4, 6, 8]

# %%
nums = [1, 2, 3, 4, 5, 6]
result = filter(lambda x: x % 2 == 0, nums)
print(list(result))
# Out:
# [2, 4, 6]

# %%
nums = [1, 2, 3, 4, 5, 6]

evens = filter(lambda x: x % 2 == 0, nums)
doubled = map(lambda x: x * 2, evens)

print(list(doubled))
# Out:
# [4, 8, 12]

# %% [markdown]
# # float

# %% [markdown]
# # frozenset()

# %%
fs = frozenset([1, 2, 3, 2, 1])
print(fs)
# Out:
# frozenset({1, 2, 3})

# %%
d = {}
d[frozenset([1, 2, 3])] = "group A"
print(d)
# Out:
# {frozenset({1, 2, 3}): 'group A'}

# %% [markdown]
# # getattr()
# - Return the value of the named attribute of object. name must be a string.
# -  If the string is the name of one of the object’s attributes, the result is the value of that attribute.

# %%
class Person:
    def __init__(self):
        self.name = "Amin"
        self.age = 30

p = Person()
print(getattr(p, "name"))
# Out:
# Amin

# %%
class Ops:
    def add(self, x, y):
        return x + y

o = Ops()

method = getattr(o, "add")
print(method(5, 8))
# Out:
# 13

# %% [markdown]
# # globals() & locals()

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'class A:\n    x = 10\n\nobj = A()\nprint(obj.x)   # 10\n\ndelattr(A, "x")\n\nprint(obj.x)',
#   'dict([1, 2, 3])',
#   'dict(1, 2, 3)',
#   'v = [1, 2, 3]\ndict(v)',
#   "v = {'a' : 1}\ndict(v)",
#   "v = {'a' : 1}\ndict(v)",
#   'dir()',
#   'dir(a)',
#   'dir(v)',
#   'dir(v)',
#   'divmod(1,4)',
#   'divmod(2,4)',
#   'divmod(5,4)',
#   'divmod(15,4)',
#   'divmod(15,4)',
#   'a = [1, 2, 3, 4]\nenumerate(a)',
#   'a = [1, 2, 3, 4]\nfor i in enumerate(a):\n    print(i)',
#   'a = [1, 2, 3, 4]\nfor i in enumerate(a):\n    print(i)',
#   'list(enumerate(a))',
#   'list(enumerate(a, 10))',
#   'list(enumerate(a, 10))',
#   'formula = "a + b * 10"\nprint(eval(formula, {"a": 2, "b": 5}))',
#   's = "{\'x\': 1, \'y\': 2}"\nd = eval(s)\nprint(d["x"])',
#   's = "{\'x\': 1, \'y\': 2}"\nd = eval(s)\nprint(d["x"])',
#   'code = """\ndef hello(name):\n    return "Hello " + name\n"""\n\nnamespace = {}\nexec(code, namespace)\n\nprint(namespace["hello"]("Amin"))',
#   'code = """\ndef hello(name):\n    return "Hello " + name\n"""\n\nnamespace = {}\nexec(code, namespace)\n\nprint(namespace["hello"]("Amin"))',
#   'code = """\ndef hello(name):\n    return "Hello " + name\n"""\n\nnamespace = {}\nexec(code, namespace)\n\nprint(namespace["hello"]("Amin"))',
#   'nums = [1, 2, 3, 4]\nresult = map(lambda x: x * 2, nums)\nprint(list(result))  ',
#   'nums = [1, 2, 3, 4, 5, 6]\nresult = filter(lambda x: x % 2 == 0, nums)\nprint(list(result))',
#   'nums = [1, 2, 3, 4, 5, 6]\n\nevens = filter(lambda x: x % 2 == 0, nums)\ndoubled = map(lambda x: x * 2, evens)\n\nprint(list(doubled))',
#   'fs = frozenset([1, 2, 3, 2, 1])\nprint(fs)',
#   'd = {}\nd[frozenset([1, 2, 3])] = "group A"\nprint(d)',
#   'class Person:\n    def __init__(self):\n        self.name = "Amin"\n        self.age = 30\n\np = Person()\nprint(getattr(p, "name"))',
#   'class Ops:\n    def add(self, x, y):\n        return x + y\n\no = Ops()\n\nmethod = getattr(o, "add")\nprint(method(5, 8))',
#   'globals()',
#   'globals()',
#   'class Ops:\n    def add(self): pass\n\no = Ops()\n\nprint(hasattr(o, "add"))   # True\nprint(hasattr(o, "mul"))   # False',
#   'class Ops:\n    def add(self): pass\n\no = Ops()\n\nprint(hasattr(o, "add"))   # True\nprint(hasattr(o, "mul"))   # False',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'x = 10\ny = 10\n\nprint(id(x))\nprint(id(y))',
#   'x = 10\ny = 10\n\nprint(id(x))\nprint(id(y))',
#   'x = 10\ny = 10\n\nprint(id(x))\nprint(id(y))',
#   'globals()'],
#  '_oh': {1: '{"dataframes": [], "user": "Amin"}',
#   2: '{"dataframes": [], "user": "Amin"}',
#   3: '{"dataframes": [], "user": "Amin"}',
#   4: '{"dataframes": [], "user": "Amin"}',
#   5: {'a': 1},
#   6: {'a': 1},
#   7: ['A',
#    'In',
#    'NamespaceMagics',
#    'Out',
#    '_',
#    '_1',
#    '_2',
#    '_3',
#    '_4',
#    '_5',
#    '_6',
#    '_7',
#    '__',
#    '__K',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__import__',
#    '__ipywidgets',
#    '__loader__',
#    '__name__',
#    '__np',
#    '__package__',
#    '__pandas',
#    '__pd',
#    '__pyspark',
#    '__session__',
#    '__spec__',
#    '__tf',
#    '__torch',
#    '__xr',
#    '_attempt_import',
#    '_check_imported',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_jupyterlab_variableinspector_Jupyter',
#    '_jupyterlab_variableinspector_changesettings',
#    '_jupyterlab_variableinspector_default',
#    '_jupyterlab_variableinspector_deletevariable',
#    '_jupyterlab_variableinspector_dict_list',
#    '_jupyterlab_variableinspector_displaywidget',
#    '_jupyterlab_variableinspector_getcontentof',
#    '_jupyterlab_variableinspector_getmatrixcontent',
#    '_jupyterlab_variableinspector_getshapeof',
#    '_jupyterlab_variableinspector_getsizeof',
#    '_jupyterlab_variableinspector_is_matrix',
#    '_jupyterlab_variableinspector_is_widget',
#    '_jupyterlab_variableinspector_maxitems',
#    '_jupyterlab_variableinspector_nms',
#    '_oh',
#    'collections',
#    'dataframe_columns',
#    'dataframe_hash',
#    'dtypes_str',
#    'exit',
#    'get_dataframes',
#    'get_ipython',
#    'getpass',
#    'hashlib',
#    'import_pandas_safely',
#    'is_data_frame',
#    'islice',
#    'json',
#    'obj',
#    'open',
#    'quit',
#    'sys',
#    'v'],
#   8: '{"dataframes": [], "user": "Amin"}',
#   9: ['__class__',
#    '__class_getitem__',
#    '__contains__',
#    '__delattr__',
#    '__delitem__',
#    '__dir__',
#    '__doc__',
#    '__eq__',
#    '__format__',
#    '__ge__',
#    '__getattribute__',
#    '__getitem__',
#    '__getstate__',
#    '__gt__',
#    '__hash__',
#    '__init__',
#    '__init_subclass__',
#    '__ior__',
#    '__iter__',
#    '__le__',
#    '__len__',
#    '__lt__',
#    '__ne__',
#    '__new__',
#    '__or__',
#    '__reduce__',
#    '__reduce_ex__',
#    '__repr__',
#    '__reversed__',
#    '__ror__',
#    '__setattr__',
#    '__setitem__',
#    '__sizeof__',
#    '__str__',
#    '__subclasshook__',
#    'clear',
#    'copy',
#    'fromkeys',
#    'get',
#    'items',
#    'keys',
#    'pop',
#    'popitem',
#    'setdefault',
#    'update',
#    'values'],
#   10: ['__class__',
#    '__class_getitem__',
#    '__contains__',
#    '__delattr__',
#    '__delitem__',
#    '__dir__',
#    '__doc__',
#    '__eq__',
#    '__format__',
#    '__ge__',
#    '__getattribute__',
#    '__getitem__',
#    '__getstate__',
#    '__gt__',
#    '__hash__',
#    '__init__',
#    '__init_subclass__',
#    '__ior__',
#    '__iter__',
#    '__le__',
#    '__len__',
#    '__lt__',
#    '__ne__',
#    '__new__',
#    '__or__',
#    '__reduce__',
#    '__reduce_ex__',
#    '__repr__',
#    '__reversed__',
#    '__ror__',
#    '__setattr__',
#    '__setitem__',
#    '__sizeof__',
#    '__str__',
#    '__subclasshook__',
#    'clear',
#    'copy',
#    'fromkeys',
#    'get',
#    'items',
#    'keys',
#    'pop',
#    'popitem',
#    'setdefault',
#    'update',
#    'values'],
#   11: (0, 1),
#   12: (0, 2),
#   13: (1, 1),
#   14: (3, 3),
#   15: (3, 3),
#   16: <enumerate at 0x1b045685c60>,
#   17: '{"dataframes": [], "user": "Amin"}',
#   18: '{"dataframes": [], "user": "Amin"}',
#   19: [(0, 1), (1, 2), (2, 3), (3, 4)],
#   20: [(10, 1), (11, 2), (12, 3), (13, 4)],
#   21: [(10, 1), (11, 2), (12, 3), (13, 4)],
#   22: '{"dataframes": [], "user": "Amin"}',
#   23: '{"dataframes": [], "user": "Amin"}',
#   24: '{"dataframes": [], "user": "Amin"}',
#   25: '{"dataframes": [], "user": "Amin"}',
#   26: '{"dataframes": [], "user": "Amin"}',
#   27: '{"dataframes": [], "user": "Amin"}',
#   28: '{"dataframes": [], "user": "Amin"}',
#   29: '{"dataframes": [], "user": "Amin"}',
#   30: '{"dataframes": [], "user": "Amin"}',
#   31: '{"dataframes": [], "user": "Amin"}',
#   32: '{"dataframes": [], "user": "Amin"}',
#   33: '{"dataframes": [], "user": "Amin"}',
#   34: '{"dataframes": [], "user": "Amin"}',
#   35: {...},
#   36: {...},
#   37: '{"dataframes": [], "user": "Amin"}',
#   38: '{"dataframes": [], "user": "Amin"}',
#   39: '{"dataframes": [], "user": "Amin"}',
#   40: '{"dataframes": [], "user": "Amin"}',
#   41: '{"dataframes": [], "user": "Amin"}',
#   42: '{"dataframes": [], "user": "Amin"}',
#   43: '{"dataframes": [], "user": "Amin"}',
#   44: '{"dataframes": [], "user": "Amin"}',
#   45: '{"dataframes": [], "user": "Amin"}',
#   46: '{"dataframes": [], "user": "Amin"}',
#   47: '{"dataframes": [], "user": "Amin"}',
#   48: '{"dataframes": [], "user": "Amin"}',
#   49: '{"dataframes": [], "user": "Amin"}',
#   50: '{"dataframes": [], "user": "Amin"}',
#   51: '{"dataframes": [], "user": "Amin"}',
#   52: '{"dataframes": [], "user": "Amin"}',
#   53: '{"dataframes": [], "user": "Amin"}',
#   54: '{"dataframes": [], "user": "Amin"}',
#   62: '{"dataframes": [], "user": "Amin"}',
#   63: '{"dataframes": [], "user": "Amin"}',
#   64: '{"dataframes": [], "user": "Amin"}',
#   65: '{"dataframes": [], "user": "Amin"}',
#   66: '{"dataframes": [], "user": "Amin"}',
#   67: '{"dataframes": [], "user": "Amin"}',
#   68: '{"dataframes": [], "user": "Amin"}',
#   69: '{"dataframes": [], "user": "Amin"}',
#   70: '{"dataframes": [], "user": "Amin"}',
#   71: '{"dataframes": [], "user": "Amin"}',
#   72: '{"dataframes": [], "user": "Amin"}',
#   73: '{"dataframes": [], "user": "Amin"}'},
#  '_dh': [WindowsPath('C:/Users/Amin')],
#  'In': ['',
#   'class A:\n    x = 10\n\nobj = A()\nprint(obj.x)   # 10\n\ndelattr(A, "x")\n\nprint(obj.x)',
#   'dict([1, 2, 3])',
#   'dict(1, 2, 3)',
#   'v = [1, 2, 3]\ndict(v)',
#   "v = {'a' : 1}\ndict(v)",
#   "v = {'a' : 1}\ndict(v)",
#   'dir()',
#   'dir(a)',
#   'dir(v)',
#   'dir(v)',
#   'divmod(1,4)',
#   'divmod(2,4)',
#   'divmod(5,4)',
#   'divmod(15,4)',
#   'divmod(15,4)',
#   'a = [1, 2, 3, 4]\nenumerate(a)',
#   'a = [1, 2, 3, 4]\nfor i in enumerate(a):\n    print(i)',
#   'a = [1, 2, 3, 4]\nfor i in enumerate(a):\n    print(i)',
#   'list(enumerate(a))',
#   'list(enumerate(a, 10))',
#   'list(enumerate(a, 10))',
#   'formula = "a + b * 10"\nprint(eval(formula, {"a": 2, "b": 5}))',
#   's = "{\'x\': 1, \'y\': 2}"\nd = eval(s)\nprint(d["x"])',
#   's = "{\'x\': 1, \'y\': 2}"\nd = eval(s)\nprint(d["x"])',
#   'code = """\ndef hello(name):\n    return "Hello " + name\n"""\n\nnamespace = {}\nexec(code, namespace)\n\nprint(namespace["hello"]("Amin"))',
#   'code = """\ndef hello(name):\n    return "Hello " + name\n"""\n\nnamespace = {}\nexec(code, namespace)\n\nprint(namespace["hello"]("Amin"))',
#   'code = """\ndef hello(name):\n    return "Hello " + name\n"""\n\nnamespace = {}\nexec(code, namespace)\n\nprint(namespace["hello"]("Amin"))',
#   'nums = [1, 2, 3, 4]\nresult = map(lambda x: x * 2, nums)\nprint(list(result))  ',
#   'nums = [1, 2, 3, 4, 5, 6]\nresult = filter(lambda x: x % 2 == 0, nums)\nprint(list(result))',
#   'nums = [1, 2, 3, 4, 5, 6]\n\nevens = filter(lambda x: x % 2 == 0, nums)\ndoubled = map(lambda x: x * 2, evens)\n\nprint(list(doubled))',
#   'fs = frozenset([1, 2, 3, 2, 1])\nprint(fs)',
#   'd = {}\nd[frozenset([1, 2, 3])] = "group A"\nprint(d)',
#   'class Person:\n    def __init__(self):\n        self.name = "Amin"\n        self.age = 30\n\np = Person()\nprint(getattr(p, "name"))',
#   'class Ops:\n    def add(self, x, y):\n        return x + y\n\no = Ops()\n\nmethod = getattr(o, "add")\nprint(method(5, 8))',
#   'globals()',
#   'globals()',
#   'class Ops:\n    def add(self): pass\n\no = Ops()\n\nprint(hasattr(o, "add"))   # True\nprint(hasattr(o, "mul"))   # False',
#   'class Ops:\n    def add(self): pass\n\no = Ops()\n\nprint(hasattr(o, "add"))   # True\nprint(hasattr(o, "mul"))   # False',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#   'x = 10\ny = 10\n\nprint(id(x))\nprint(id(y))',
#   'x = 10\ny = 10\n\nprint(id(x))\nprint(id(y))',
#   'x = 10\ny = 10\n\nprint(id(x))\nprint(id(y))',
#   'globals()'],
#  'Out': {1: '{"dataframes": [], "user": "Amin"}',
#   2: '{"dataframes": [], "user": "Amin"}',
#   3: '{"dataframes": [], "user": "Amin"}',
#   4: '{"dataframes": [], "user": "Amin"}',
#   5: {'a': 1},
#   6: {'a': 1},
#   7: ['A',
#    'In',
#    'NamespaceMagics',
#    'Out',
#    '_',
#    '_1',
#    '_2',
#    '_3',
#    '_4',
#    '_5',
#    '_6',
#    '_7',
#    '__',
#    '__K',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__import__',
#    '__ipywidgets',
#    '__loader__',
#    '__name__',
#    '__np',
#    '__package__',
#    '__pandas',
#    '__pd',
#    '__pyspark',
#    '__session__',
#    '__spec__',
#    '__tf',
#    '__torch',
#    '__xr',
#    '_attempt_import',
#    '_check_imported',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_jupyterlab_variableinspector_Jupyter',
#    '_jupyterlab_variableinspector_changesettings',
#    '_jupyterlab_variableinspector_default',
#    '_jupyterlab_variableinspector_deletevariable',
#    '_jupyterlab_variableinspector_dict_list',
#    '_jupyterlab_variableinspector_displaywidget',
#    '_jupyterlab_variableinspector_getcontentof',
#    '_jupyterlab_variableinspector_getmatrixcontent',
#    '_jupyterlab_variableinspector_getshapeof',
#    '_jupyterlab_variableinspector_getsizeof',
#    '_jupyterlab_variableinspector_is_matrix',
#    '_jupyterlab_variableinspector_is_widget',
#    '_jupyterlab_variableinspector_maxitems',
#    '_jupyterlab_variableinspector_nms',
#    '_oh',
#    'collections',
#    'dataframe_columns',
#    'dataframe_hash',
#    'dtypes_str',
#    'exit',
#    'get_dataframes',
#    'get_ipython',
#    'getpass',
#    'hashlib',
#    'import_pandas_safely',
#    'is_data_frame',
#    'islice',
#    'json',
#    'obj',
#    'open',
#    'quit',
#    'sys',
#    'v'],
#   8: '{"dataframes": [], "user": "Amin"}',
#   9: ['__class__',
#    '__class_getitem__',
#    '__contains__',
#    '__delattr__',
#    '__delitem__',
#    '__dir__',
#    '__doc__',
#    '__eq__',
#    '__format__',
#    '__ge__',
#    '__getattribute__',
#    '__getitem__',
#    '__getstate__',
#    '__gt__',
#    '__hash__',
#    '__init__',
#    '__init_subclass__',
#    '__ior__',
#    '__iter__',
#    '__le__',
#    '__len__',
#    '__lt__',
#    '__ne__',
#    '__new__',
#    '__or__',
#    '__reduce__',
#    '__reduce_ex__',
#    '__repr__',
#    '__reversed__',
#    '__ror__',
#    '__setattr__',
#    '__setitem__',
#    '__sizeof__',
#    '__str__',
#    '__subclasshook__',
#    'clear',
#    'copy',
#    'fromkeys',
#    'get',
#    'items',
#    'keys',
#    'pop',
#    'popitem',
#    'setdefault',
#    'update',
#    'values'],
#   10: ['__class__',
#    '__class_getitem__',
#    '__contains__',
#    '__delattr__',
#    '__delitem__',
#    '__dir__',
#    '__doc__',
#    '__eq__',
#    '__format__',
#    '__ge__',
#    '__getattribute__',
#    '__getitem__',
#    '__getstate__',
#    '__gt__',
#    '__hash__',
#    '__init__',
#    '__init_subclass__',
#    '__ior__',
#    '__iter__',
#    '__le__',
#    '__len__',
#    '__lt__',
#    '__ne__',
#    '__new__',
#    '__or__',
#    '__reduce__',
#    '__reduce_ex__',
#    '__repr__',
#    '__reversed__',
#    '__ror__',
#    '__setattr__',
#    '__setitem__',
#    '__sizeof__',
#    '__str__',
#    '__subclasshook__',
#    'clear',
#    'copy',
#    'fromkeys',
#    'get',
#    'items',
#    'keys',
#    'pop',
#    'popitem',
#    'setdefault',
#    'update',
#    'values'],
#   11: (0, 1),
#   12: (0, 2),
#   13: (1, 1),
#   14: (3, 3),
#   15: (3, 3),
#   16: <enumerate at 0x1b045685c60>,
#   17: '{"dataframes": [], "user": "Amin"}',
#   18: '{"dataframes": [], "user": "Amin"}',
#   19: [(0, 1), (1, 2), (2, 3), (3, 4)],
#   20: [(10, 1), (11, 2), (12, 3), (13, 4)],
#   21: [(10, 1), (11, 2), (12, 3), (13, 4)],
#   22: '{"dataframes": [], "user": "Amin"}',
#   23: '{"dataframes": [], "user": "Amin"}',
#   24: '{"dataframes": [], "user": "Amin"}',
#   25: '{"dataframes": [], "user": "Amin"}',
#   26: '{"dataframes": [], "user": "Amin"}',
#   27: '{"dataframes": [], "user": "Amin"}',
#   28: '{"dataframes": [], "user": "Amin"}',
#   29: '{"dataframes": [], "user": "Amin"}',
#   30: '{"dataframes": [], "user": "Amin"}',
#   31: '{"dataframes": [], "user": "Amin"}',
#   32: '{"dataframes": [], "user": "Amin"}',
#   33: '{"dataframes": [], "user": "Amin"}',
#   34: '{"dataframes": [], "user": "Amin"}',
#   35: {...},
#   36: {...},
#   37: '{"dataframes": [], "user": "Amin"}',
#   38: '{"dataframes": [], "user": "Amin"}',
#   39: '{"dataframes": [], "user": "Amin"}',
#   40: '{"dataframes": [], "user": "Amin"}',
#   41: '{"dataframes": [], "user": "Amin"}',
#   42: '{"dataframes": [], "user": "Amin"}',
#   43: '{"dataframes": [], "user": "Amin"}',
#   44: '{"dataframes": [], "user": "Amin"}',
#   45: '{"dataframes": [], "user": "Amin"}',
#   46: '{"dataframes": [], "user": "Amin"}',
#   47: '{"dataframes": [], "user": "Amin"}',
#   48: '{"dataframes": [], "user": "Amin"}',
#   49: '{"dataframes": [], "user": "Amin"}',
#   50: '{"dataframes": [], "user": "Amin"}',
#   51: '{"dataframes": [], "user": "Amin"}',
#   52: '{"dataframes": [], "user": "Amin"}',
#   53: '{"dataframes": [], "user": "Amin"}',
#   54: '{"dataframes": [], "user": "Amin"}',
#   62: '{"dataframes": [], "user": "Amin"}',
#   63: '{"dataframes": [], "user": "Amin"}',
#   64: '{"dataframes": [], "user": "Amin"}',
#   65: '{"dataframes": [], "user": "Amin"}',
#   66: '{"dataframes": [], "user": "Amin"}',
#   67: '{"dataframes": [], "user": "Amin"}',
#   68: '{"dataframes": [], "user": "Amin"}',
#   69: '{"dataframes": [], "user": "Amin"}',
#   70: '{"dataframes": [], "user": "Amin"}',
#   71: '{"dataframes": [], "user": "Amin"}',
#   72: '{"dataframes": [], "user": "Amin"}',
#   73: '{"dataframes": [], "user": "Amin"}'},
#  'get_ipython': <function IPython.core.getipython.get_ipython()>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1b041ab0440>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1b041ab0440>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': '{"dataframes": [], "user": "Amin"}',
#  '__': '{"dataframes": [], "user": "Amin"}',
#  '___': '{"dataframes": [], "user": "Amin"}',
#  '__session__': 'C:\\Users\\Amin\\Built-in Functions.ipynb',
#  'json': <module 'json' from 'A:\\apps\\anaconda\\Lib\\json\\__init__.py'>,
#  'sys': <module 'sys' (built-in)>,
#  '__import__': <function _frozen_importlib.__import__(name, globals=None, locals=None, fromlist=(), level=0)>,
#  'islice': itertools.islice,
#  'collections': <module 'collections' from 'A:\\apps\\anaconda\\Lib\\collections\\__init__.py'>,
#  'NamespaceMagics': IPython.core.magics.namespace.NamespaceMagics,
#  '_jupyterlab_variableinspector_nms': <IPython.core.magics.namespace.NamespaceMagics at 0x1b040389e50>,
#  '_jupyterlab_variableinspector_Jupyter': <ipykernel.zmqshell.ZMQInteractiveShell at 0x1b041a1aba0>,
#  '_jupyterlab_variableinspector_maxitems': 10,
#  '__np': None,
#  '__pd': None,
#  '__pyspark': None,
#  '__tf': None,
#  '__K': None,
#  '__torch': None,
#  '__ipywidgets': None,
#  '__xr': None,
#  '_attempt_import': <function __main__._attempt_import(module)>,
#  '_check_imported': <function __main__._check_imported()>,
#  '_jupyterlab_variableinspector_changesettings': <function __main__._jupyterlab_variableinspector_changesettings(maxitems, **kwargs)>,
#  '_jupyterlab_variableinspector_getsizeof': <function __main__._jupyterlab_variableinspector_getsizeof(x)>,
#  '_jupyterlab_variableinspector_getshapeof': <function __main__._jupyterlab_variableinspector_getshapeof(x)>,
#  '_jupyterlab_variableinspector_getcontentof': <function __main__._jupyterlab_variableinspector_getcontentof(x)>,
#  '_jupyterlab_variableinspector_is_matrix': <function __main__._jupyterlab_variableinspector_is_matrix(x)>,
#  '_jupyterlab_variableinspector_is_widget': <function __main__._jupyterlab_variableinspector_is_widget(x)>,
#  '_jupyterlab_variableinspector_dict_list': <function __main__._jupyterlab_variableinspector_dict_list()>,
#  '_jupyterlab_variableinspector_getmatrixcontent': <function __main__._jupyterlab_variableinspector_getmatrixcontent(x, max_rows=10000)>,
#  '_jupyterlab_variableinspector_displaywidget': <function __main__._jupyterlab_variableinspector_displaywidget(widget)>,
#  '_jupyterlab_variableinspector_default': <function __main__._jupyterlab_variableinspector_default(o)>,
#  '_jupyterlab_variableinspector_deletevariable': <function __main__._jupyterlab_variableinspector_deletevariable(x)>,
#  'getpass': <module 'getpass' from 'A:\\apps\\anaconda\\Lib\\getpass.py'>,
#  'hashlib': <module 'hashlib' from 'A:\\apps\\anaconda\\Lib\\hashlib.py'>,
#  'import_pandas_safely': <function __main__.import_pandas_safely()>,
#  '__pandas': <module 'pandas' from 'A:\\apps\\anaconda\\Lib\\site-packages\\pandas\\__init__.py'>,
#  'is_data_frame': <function __main__.is_data_frame(v: str)>,
#  'dataframe_columns': <function __main__.dataframe_columns(var)>,
#  'dtypes_str': <function __main__.dtypes_str(frame)>,
#  'dataframe_hash': <function __main__.dataframe_hash(var)>,
#  'get_dataframes': <function __main__.get_dataframes()>,
#  '_1': '{"dataframes": [], "user": "Amin"}',
#  '_i': 'x = 10\ny = 10\n\nprint(id(x))\nprint(id(y))',
#  '_ii': 'x = 10\ny = 10\n\nprint(id(x))\nprint(id(y))',
#  '_iii': 'x = 10\ny = 10\n\nprint(id(x))\nprint(id(y))',
#  '_i1': 'class A:\n    x = 10\n\nobj = A()\nprint(obj.x)   # 10\n\ndelattr(A, "x")\n\nprint(obj.x)',
#  'A': __main__.A,
#  'obj': <__main__.A at 0x1b043fe7b60>,
#  '_2': '{"dataframes": [], "user": "Amin"}',
#  '_i2': 'dict([1, 2, 3])',
#  '_3': '{"dataframes": [], "user": "Amin"}',
#  '_i3': 'dict(1, 2, 3)',
#  '_4': '{"dataframes": [], "user": "Amin"}',
#  '_i4': 'v = [1, 2, 3]\ndict(v)',
#  'v': {'a': 1},
#  '_5': {'a': 1},
#  '_i5': "v = {'a' : 1}\ndict(v)",
#  '_6': {'a': 1},
#  '_i6': "v = {'a' : 1}\ndict(v)",
#  '_7': ['A',
#   'In',
#   'NamespaceMagics',
#   'Out',
#   '_',
#   '_1',
#   '_2',
#   '_3',
#   '_4',
#   '_5',
#   '_6',
#   '_7',
#   '__',
#   '__K',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__import__',
#   '__ipywidgets',
#   '__loader__',
#   '__name__',
#   '__np',
#   '__package__',
#   '__pandas',
#   '__pd',
#   '__pyspark',
#   '__session__',
#   '__spec__',
#   '__tf',
#   '__torch',
#   '__xr',
#   '_attempt_import',
#   '_check_imported',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_i3',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_jupyterlab_variableinspector_Jupyter',
#   '_jupyterlab_variableinspector_changesettings',
#   '_jupyterlab_variableinspector_default',
#   '_jupyterlab_variableinspector_deletevariable',
#   '_jupyterlab_variableinspector_dict_list',
#   '_jupyterlab_variableinspector_displaywidget',
#   '_jupyterlab_variableinspector_getcontentof',
#   '_jupyterlab_variableinspector_getmatrixcontent',
#   '_jupyterlab_variableinspector_getshapeof',
#   '_jupyterlab_variableinspector_getsizeof',
#   '_jupyterlab_variableinspector_is_matrix',
#   '_jupyterlab_variableinspector_is_widget',
#   '_jupyterlab_variableinspector_maxitems',
#   '_jupyterlab_variableinspector_nms',
#   '_oh',
#   'collections',
#   'dataframe_columns',
#   'dataframe_hash',
#   'dtypes_str',
#   'exit',
#   'get_dataframes',
#   'get_ipython',
#   'getpass',
#   'hashlib',
#   'import_pandas_safely',
#   'is_data_frame',
#   'islice',
#   'json',
#   'obj',
#   'open',
#   'quit',
#   'sys',
#   'v'],
#  '_i7': 'dir()',
#  '_8': '{"dataframes": [], "user": "Amin"}',
#  '_i8': 'dir(a)',
#  '_9': ['__class__',
#   '__class_getitem__',
#   '__contains__',
#   '__delattr__',
#   '__delitem__',
#   '__dir__',
#   '__doc__',
#   '__eq__',
#   '__format__',
#   '__ge__',
#   '__getattribute__',
#   '__getitem__',
#   '__getstate__',
#   '__gt__',
#   '__hash__',
#   '__init__',
#   '__init_subclass__',
#   '__ior__',
#   '__iter__',
#   '__le__',
#   '__len__',
#   '__lt__',
#   '__ne__',
#   '__new__',
#   '__or__',
#   '__reduce__',
#   '__reduce_ex__',
#   '__repr__',
#   '__reversed__',
#   '__ror__',
#   '__setattr__',
#   '__setitem__',
#   '__sizeof__',
#   '__str__',
#   '__subclasshook__',
#   'clear',
#   'copy',
#   'fromkeys',
#   'get',
#   'items',
#   'keys',
#   'pop',
#   'popitem',
#   'setdefault',
#   'update',
#   'values'],
#  '_i9': 'dir(v)',
#  '_10': ['__class__',
#   '__class_getitem__',
#   '__contains__',
#   '__delattr__',
#   '__delitem__',
#   '__dir__',
#   '__doc__',
#   '__eq__',
#   '__format__',
#   '__ge__',
#   '__getattribute__',
#   '__getitem__',
#   '__getstate__',
#   '__gt__',
#   '__hash__',
#   '__init__',
#   '__init_subclass__',
#   '__ior__',
#   '__iter__',
#   '__le__',
#   '__len__',
#   '__lt__',
#   '__ne__',
#   '__new__',
#   '__or__',
#   '__reduce__',
#   '__reduce_ex__',
#   '__repr__',
#   '__reversed__',
#   '__ror__',
#   '__setattr__',
#   '__setitem__',
#   '__sizeof__',
#   '__str__',
#   '__subclasshook__',
#   'clear',
#   'copy',
#   'fromkeys',
#   'get',
#   'items',
#   'keys',
#   'pop',
#   'popitem',
#   'setdefault',
#   'update',
#   'values'],
#  '_i10': 'dir(v)',
#  '_11': (0, 1),
#  '_i11': 'divmod(1,4)',
#  '_12': (0, 2),
#  '_i12': 'divmod(2,4)',
#  '_13': (1, 1),
#  '_i13': 'divmod(5,4)',
#  '_14': (3, 3),
#  '_i14': 'divmod(15,4)',
#  '_15': (3, 3),
#  '_i15': 'divmod(15,4)',
#  '_16': <enumerate at 0x1b045685c60>,
#  '_i16': 'a = [1, 2, 3, 4]\nenumerate(a)',
#  'a': [1, 2, 3, 4],
#  '_17': '{"dataframes": [], "user": "Amin"}',
#  '_i17': 'a = [1, 2, 3, 4]\nfor i in enumerate(a):\n    print(i)',
#  'i': (3, 4),
#  '_18': '{"dataframes": [], "user": "Amin"}',
#  '_i18': 'a = [1, 2, 3, 4]\nfor i in enumerate(a):\n    print(i)',
#  '_19': [(0, 1), (1, 2), (2, 3), (3, 4)],
#  '_i19': 'list(enumerate(a))',
#  '_20': [(10, 1), (11, 2), (12, 3), (13, 4)],
#  '_i20': 'list(enumerate(a, 10))',
#  '_21': [(10, 1), (11, 2), (12, 3), (13, 4)],
#  '_i21': 'list(enumerate(a, 10))',
#  '_22': '{"dataframes": [], "user": "Amin"}',
#  '_i22': 'formula = "a + b * 10"\nprint(eval(formula, {"a": 2, "b": 5}))',
#  'formula': 'a + b * 10',
#  '_23': '{"dataframes": [], "user": "Amin"}',
#  '_i23': 's = "{\'x\': 1, \'y\': 2}"\nd = eval(s)\nprint(d["x"])',
#  's': "{'x': 1, 'y': 2}",
#  'd': {frozenset({1, 2, 3}): 'group A'},
#  '_24': '{"dataframes": [], "user": "Amin"}',
#  '_i24': 's = "{\'x\': 1, \'y\': 2}"\nd = eval(s)\nprint(d["x"])',
#  '_25': '{"dataframes": [], "user": "Amin"}',
#  '_i25': 'code = """\ndef hello(name):\n    return "Hello " + name\n"""\n\nnamespace = {}\nexec(code, namespace)\n\nprint(namespace["hello"]("Amin"))',
#  'code': '\ndef hello(name):\n    return "Hello " + name\n',
#  'namespace': {'__builtins__': {'__name__': 'builtins',
#    '__doc__': "Built-in functions, types, exceptions, and other objects.\n\nThis module provides direct access to all 'built-in'\nidentifiers of Python; for example, builtins.len is\nthe full name for the built-in function len().\n\nThis module is not normally accessed explicitly by most\napplications, but can be useful in modules that provide\nobjects with the same name as a built-in value, but in\nwhich the built-in of that name is also needed.",
#    '__package__': '',
#    '__loader__': _frozen_importlib.BuiltinImporter,
#    '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'),
#    '__build_class__': <function __build_class__>,
#    '__import__': <function __import__(name, globals=None, locals=None, fromlist=(), level=0)>,
#    'abs': <function abs(x, /)>,
#    'all': <function all(iterable, /)>,
#    'any': <function any(iterable, /)>,
#    'ascii': <function ascii(obj, /)>,
#    'bin': <function bin(number, /)>,
#    'breakpoint': <function breakpoint(*args, **kws)>,
#    'callable': <function callable(obj, /)>,
#    'chr': <function chr(i, /)>,
#    'compile': <function compile(source, filename, mode, flags=0, dont_inherit=False, optimize=-1, *, _feature_version=-1)>,
#    'delattr': <function delattr(obj, name, /)>,
#    'dir': <function dir>,
#    'divmod': <function divmod(x, y, /)>,
#    'eval': <function eval(source, /, globals=None, locals=None)>,
#    'exec': <function exec(source, /, globals=None, locals=None, *, closure=None)>,
#    'format': <function format(value, format_spec='', /)>,
#    'getattr': <function getattr>,
#    'globals': <function globals()>,
#    'hasattr': <function hasattr(obj, name, /)>,
#    'hash': <function hash(obj, /)>,
#    'hex': <function hex(number, /)>,
#    'id': <function id(obj, /)>,
#    'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000001B040411160>>,
#    'isinstance': <function isinstance(obj, class_or_tuple, /)>,
#    'issubclass': <function issubclass(cls, class_or_tuple, /)>,
#    'iter': <function iter>,
#    'aiter': <function aiter(async_iterable, /)>,
#    'len': <function len(obj, /)>,
#    'locals': <function locals()>,
#    'max': <function max>,
#    'min': <function min>,
#    'next': <function next>,
#    'anext': <function anext>,
#    'oct': <function oct(number, /)>,
#    'ord': <function ord(c, /)>,
#    'pow': <function pow(base, exp, mod=None)>,
#    'print': <function print(*args, sep=' ', end='\n', file=None, flush=False)>,
#    'repr': <function repr(obj, /)>,
#    'round': <function round(number, ndigits=None)>,
#    'setattr': <function setattr(obj, name, value, /)>,
#    'sorted': <function sorted(iterable, /, *, key=None, reverse=False)>,
#    'sum': <function sum(iterable, /, start=0)>,
#    'vars': <function vars>,
#    'None': None,
#    'Ellipsis': Ellipsis,
#    'NotImplemented': NotImplemented,
#    'False': False,
#    'True': True,
#    'bool': bool,
#    'memoryview': memoryview,
#    'bytearray': bytearray,
#    'bytes': bytes,
#    'classmethod': classmethod,
#    'complex': complex,
#    'dict': dict,
#    'enumerate': enumerate,
#    'filter': filter,
#    'float': float,
#    'frozenset': frozenset,
#    'property': property,
#    'int': int,
#    'list': list,
#    'map': map,
#    'object': object,
#    'range': range,
#    'reversed': reversed,
#    'set': set,
#    'slice': slice,
#    'staticmethod': staticmethod,
#    'str': str,
#    'super': super,
#    'tuple': tuple,
#    'type': type,
#    'zip': zip,
#    '__debug__': True,
#    'BaseException': BaseException,
#    'BaseExceptionGroup': BaseExceptionGroup,
#    'Exception': Exception,
#    'GeneratorExit': GeneratorExit,
#    'KeyboardInterrupt': KeyboardInterrupt,
#    'SystemExit': SystemExit,
#    'ArithmeticError': ArithmeticError,
#    'AssertionError': AssertionError,
#    'AttributeError': AttributeError,
#    'BufferError': BufferError,
#    'EOFError': EOFError,
#    'ImportError': ImportError,
#    'LookupError': LookupError,
#    'MemoryError': MemoryError,
#    'NameError': NameError,
#    'OSError': OSError,
#    'ReferenceError': ReferenceError,
#    'RuntimeError': RuntimeError,
#    'StopAsyncIteration': StopAsyncIteration,
#    'StopIteration': StopIteration,
#    'SyntaxError': SyntaxError,
#    'SystemError': SystemError,
#    'TypeError': TypeError,
#    'ValueError': ValueError,
#    'Warning': Warning,
#    'FloatingPointError': FloatingPointError,
#    'OverflowError': OverflowError,
#    'ZeroDivisionError': ZeroDivisionError,
#    'BytesWarning': BytesWarning,
#    'DeprecationWarning': DeprecationWarning,
#    'EncodingWarning': EncodingWarning,
#    'FutureWarning': FutureWarning,
#    'ImportWarning': ImportWarning,
#    'PendingDeprecationWarning': PendingDeprecationWarning,
#    'ResourceWarning': ResourceWarning,
#    'RuntimeWarning': RuntimeWarning,
#    'SyntaxWarning': SyntaxWarning,
#    'UnicodeWarning': UnicodeWarning,
#    'UserWarning': UserWarning,
#    'BlockingIOError': BlockingIOError,
#    'ChildProcessError': ChildProcessError,
#    'ConnectionError': ConnectionError,
#    'FileExistsError': FileExistsError,
#    'FileNotFoundError': FileNotFoundError,
#    'InterruptedError': InterruptedError,
#    'IsADirectoryError': IsADirectoryError,
#    'NotADirectoryError': NotADirectoryError,
#    'PermissionError': PermissionError,
#    'ProcessLookupError': ProcessLookupError,
#    'TimeoutError': TimeoutError,
#    'IndentationError': IndentationError,
#    '_IncompleteInputError': _IncompleteInputError,
#    'IndexError': IndexError,
#    'KeyError': KeyError,
#    'ModuleNotFoundError': ModuleNotFoundError,
#    'NotImplementedError': NotImplementedError,
#    'PythonFinalizationError': PythonFinalizationError,
#    'RecursionError': RecursionError,
#    'UnboundLocalError': UnboundLocalError,
#    'UnicodeError': UnicodeError,
#    'BrokenPipeError': BrokenPipeError,
#    'ConnectionAbortedError': ConnectionAbortedError,
#    'ConnectionRefusedError': ConnectionRefusedError,
#    'ConnectionResetError': ConnectionResetError,
#    'TabError': TabError,
#    'UnicodeDecodeError': UnicodeDecodeError,
#    'UnicodeEncodeError': UnicodeEncodeError,
#    'UnicodeTranslateError': UnicodeTranslateError,
#    'ExceptionGroup': ExceptionGroup,
#    'EnvironmentError': OSError,
#    'IOError': OSError,
#    'WindowsError': OSError,
#    'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#    'copyright': Copyright (c) 2001-2024 Python Software Foundation.
#    All Rights Reserved.
#
#    Copyright (c) 2000 BeOpen.com.
#    All Rights Reserved.
#
#    Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#    All Rights Reserved.
#
#    Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#    All Rights Reserved.,
#    'credits':     Thanks to CWI, CNRI, BeOpen, Zope Corporation, the Python Software
#        Foundation, and a cast of thousands for supporting Python
#        development.  See www.python.org for more information.,
#    'license': See https://www.python.org/psf/license/,
#    'help': Type help() for interactive help, or help(object) for help about object.,
#    'execfile': <function _pydev_bundle._pydev_execfile.execfile(file, glob=None, loc=None)>,
#    'runfile': <function _pydev_bundle.pydev_umd.runfile(filename, args=None, wdir=None, namespace=None)>,
#    '__IPYTHON__': True,
#    'display': <function IPython.core.display_functions.display(*objs, include=None, exclude=None, metadata=None, transient=None, display_id=None, raw=False, clear=False, **kwargs)>,
#    'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001B041A1ABA0>>},
#   'hello': <function hello(name)>},
#  '_26': '{"dataframes": [], "user": "Amin"}',
#  '_i26': 'code = """\ndef hello(name):\n    return "Hello " + name\n"""\n\nnamespace = {}\nexec(code, namespace)\n\nprint(namespace["hello"]("Amin"))',
#  '_27': '{"dataframes": [], "user": "Amin"}',
#  '_i27': 'code = """\ndef hello(name):\n    return "Hello " + name\n"""\n\nnamespace = {}\nexec(code, namespace)\n\nprint(namespace["hello"]("Amin"))',
#  '_28': '{"dataframes": [], "user": "Amin"}',
#  '_i28': 'nums = [1, 2, 3, 4]\nresult = map(lambda x: x * 2, nums)\nprint(list(result))  ',
#  'nums': [1, 2, 3, 4, 5, 6],
#  'result': <filter at 0x1b045a09e10>,
#  '_29': '{"dataframes": [], "user": "Amin"}',
#  '_i29': 'nums = [1, 2, 3, 4, 5, 6]\nresult = filter(lambda x: x % 2 == 0, nums)\nprint(list(result))',
#  '_30': '{"dataframes": [], "user": "Amin"}',
#  '_i30': 'nums = [1, 2, 3, 4, 5, 6]\n\nevens = filter(lambda x: x % 2 == 0, nums)\ndoubled = map(lambda x: x * 2, evens)\n\nprint(list(doubled))',
#  'evens': <filter at 0x1b045a0a500>,
#  'doubled': <map at 0x1b045a0bd60>,
#  '_31': '{"dataframes": [], "user": "Amin"}',
#  '_i31': 'fs = frozenset([1, 2, 3, 2, 1])\nprint(fs)',
#  'fs': frozenset({1, 2, 3}),
#  '_32': '{"dataframes": [], "user": "Amin"}',
#  '_i32': 'd = {}\nd[frozenset([1, 2, 3])] = "group A"\nprint(d)',
#  '_33': '{"dataframes": [], "user": "Amin"}',
#  '_i33': 'class Person:\n    def __init__(self):\n        self.name = "Amin"\n        self.age = 30\n\np = Person()\nprint(getattr(p, "name"))',
#  'Person': __main__.Person,
#  'p': <__main__.Person at 0x1b044175be0>,
#  '_34': '{"dataframes": [], "user": "Amin"}',
#  '_i34': 'class Ops:\n    def add(self, x, y):\n        return x + y\n\no = Ops()\n\nmethod = getattr(o, "add")\nprint(method(5, 8))',
#  'Ops': __main__.Ops,
#  'o': <__main__.Ops at 0x1b044175e80>,
#  'method': <bound method Ops.add of <__main__.Ops object at 0x000001B044175940>>,
#  '_35': {...},
#  '_i35': 'globals()',
#  '_36': {...},
#  '_i36': 'globals()',
#  '_37': '{"dataframes": [], "user": "Amin"}',
#  '_i37': 'class Ops:\n    def add(self): pass\n\no = Ops()\n\nprint(hasattr(o, "add"))   # True\nprint(hasattr(o, "mul"))   # False',
#  '_38': '{"dataframes": [], "user": "Amin"}',
#  '_i38': 'class Ops:\n    def add(self): pass\n\no = Ops()\n\nprint(hasattr(o, "add"))   # True\nprint(hasattr(o, "mul"))   # False',
#  '_39': '{"dataframes": [], "user": "Amin"}',
#  '_i39': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_40': '{"dataframes": [], "user": "Amin"}',
#  '_i40': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_41': '{"dataframes": [], "user": "Amin"}',
#  '_i41': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_42': '{"dataframes": [], "user": "Amin"}',
#  '_i42': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_43': '{"dataframes": [], "user": "Amin"}',
#  '_i43': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_44': '{"dataframes": [], "user": "Amin"}',
#  '_i44': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_45': '{"dataframes": [], "user": "Amin"}',
#  '_i45': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_46': '{"dataframes": [], "user": "Amin"}',
#  '_i46': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_47': '{"dataframes": [], "user": "Amin"}',
#  '_i47': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_48': '{"dataframes": [], "user": "Amin"}',
#  '_i48': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_49': '{"dataframes": [], "user": "Amin"}',
#  '_i49': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_50': '{"dataframes": [], "user": "Amin"}',
#  '_i50': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_51': '{"dataframes": [], "user": "Amin"}',
#  '_i51': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_52': '{"dataframes": [], "user": "Amin"}',
#  '_i52': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_53': '{"dataframes": [], "user": "Amin"}',
#  '_i53': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_54': '{"dataframes": [], "user": "Amin"}',
#  '_i54': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_i55': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_i56': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_i57': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_i58': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_i59': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_i60': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_i61': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_62': '{"dataframes": [], "user": "Amin"}',
#  '_i62': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_63': '{"dataframes": [], "user": "Amin"}',
#  '_i63': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_64': '{"dataframes": [], "user": "Amin"}',
#  '_i64': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_65': '{"dataframes": [], "user": "Amin"}',
#  '_i65': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_66': '{"dataframes": [], "user": "Amin"}',
#  '_i66': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_67': '{"dataframes": [], "user": "Amin"}',
#  '_i67': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_68': '{"dataframes": [], "user": "Amin"}',
#  '_i68': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_69': '{"dataframes": [], "user": "Amin"}',
#  '_i69': 'print(hash("hello"))\nprint(hash(123))\nprint(hash((1, 2, 3)))',
#  '_70': '{"dataframes": [], "user": "Amin"}',
#  '_i70': 'x = 10\ny = 10\n\nprint(id(x))\nprint(id(y))',
#  'x': 10,
#  'y': 10,
#  '_71': '{"dataframes": [], "user": "Amin"}',
#  '_i71': 'x = 10\ny = 10\n\nprint(id(x))\nprint(id(y))',
#  '_72': '{"dataframes": [], "user": "Amin"}',
#  '_i72': 'x = 10\ny = 10\n\nprint(id(x))\nprint(id(y))',
#  '_73': '{"dataframes": [], "user": "Amin"}',
#  '_i73': 'globals()'}

# %% [markdown]
# # hasattr()

# %%
class Ops:
    def add(self): pass

o = Ops()

print(hasattr(o, "add"))   # True
print(hasattr(o, "mul"))   # False
# Out:
# True
# False

# %% [markdown]
# # hash()

# %%
print(hash("hello"))
print(hash(123))
print(hash((1, 2, 3)))
# Out:
# 3734397352599044585
# 123
# 529344067295497451

# %% [markdown]
# # hex() & int()

# %% [markdown]
# # id()
# - Return the “identity” of an object.
# -  This is an integer which is guaranteed to be unique and constant for this object during its lifetime.
# -   Two objects with non-overlapping lifetimes may have the same id() value.

# %%
x = 10
y = 10

print(id(x))
print(id(y))
# Out:
# 140713472996552
# 140713472996552

# %% [markdown]
# # isinstance() & issubclass() & len() & list() & max() & min() & open() & pow() & set() & sorted()

# %% [markdown]
# # ord()
# - If the argument is a one-character string, return the Unicode code point of that character
# - If the argument is a bytes or bytearray object of length 1, return its single byte value

# %%
ord(b'9')
# Out:
# 57

# %% [markdown]
# # reversed()
# - Return a reverse iterator.

# %%
a = [1,2,3]
list(reversed(a))
# Out:
# [3, 2, 1]

# %% [markdown]
# # round()
# - Return number rounded to ndigits precision after the decimal point. If ndigits is omitted or is None, it returns the nearest integer to its input.

# %%
round(99.99123, ndigits=2)
# Out:
# 99.99

# %% [markdown]
# # slice()
# - Return a slice object representing the set of indices specified by range(start, stop, step). The start and step arguments default to None.

# %%
a = slice(1, 10, 2)
a
# Out:
# slice(1, 10, 2)

# %% [markdown]
# # zip()
# - Iterate over several iterables in parallel, producing tuples with an item from each one.

# %%
for item in zip([1, 2, 3], ['sugar', 'spice', 'everything nice']):
    print(item)
# Out:
# (1, 'sugar')
# (2, 'spice')
# (3, 'everything nice')
